# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Female Model: Preprocessing

# %%
import xgboost as xgb
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFECV
from imblearn.over_sampling import SMOTE
import warnings

female_data = pd.read_csv('/kaggle/input/female-data/female_data.csv')
print(female_data.columns)
female_columns_to_drop = ['Family_Diabetes', 'Smoking', 'Alcohol', 'RegularMedicine', 'Stress', 'Pdiabetes', 'Diabetic', 'Diabetes_Status', 'CholCheck', 'Stroke', 'HeartDiseaseorAttack', 'AnyHealthcare',
       'NoDocbcCost', 'MentHlth', 'DiffWalk',
       'Education', 'Income', 'Glucose', 'SkinThickness', 'Insulin',
       'DiabetesPedigreeFunction', 'unexplained prenetal loss', 'Large Child or Birth Default', 'Sedentary Lifestyle', 'Polyuria', 'Polydipsia', 'weakness', 'Polyphagia', 'Genital thrush',
       'Itching', 'Irritability', 'delayed healing', 'partial paresis',
       'muscle stiffness', 'Alopecia', 'Patient_ID', 'Obesity']

X_female = female_data.drop(columns=female_columns_to_drop, axis=1)
y_female = female_data['Diabetes_Status']

print(X_female.columns)
# Out:
# Index(['Age', 'Family_Diabetes', 'HighBP', 'PhysicallyActive', 'BMI',
#        'Smoking', 'Alcohol', 'Sleep', 'SoundSleep', 'RegularMedicine',
#        'JunkFood', 'Stress', 'BPLevel', 'Pregnancies', 'Pdiabetes',
#        'UriationFreq', 'Diabetic', 'Diabetes_Status', 'HighChol', 'CholCheck',
#        'Stroke', 'HeartDiseaseorAttack', 'Fruits', 'Veggies', 'AnyHealthcare',
#        'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk',
#        'Education', 'Income', 'Glucose', 'SkinThickness', 'Insulin',
#        'DiabetesPedigreeFunction', 'Gestation in previous Pregnancy',
#        'unexplained prenetal loss', 'Large Child or Birth Default', 'PCOS',
#        'Sedentary Lifestyle', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'Patient_ID', 'Pregnant'],
#       dtype='object')
# Index(['Age', 'HighBP', 'PhysicallyActive', 'BMI', 'Sleep', 'SoundSleep',
#        'JunkFood', 'BPLevel', 'Pregnancies', 'UriationFreq', 'HighChol',
#        'Fruits', 'Veggies', 'GenHlth', 'PhysHlth',
#        'Gestation in previous Pregnancy', 'PCOS', 'sudden weight loss',
#        'visual blurring', 'Pregnant'],
#       dtype='object')

# %%
# Split the data
X_train_female, X_val_female, y_train_female, y_val_female = train_test_split(X_female, y_female, test_size=0.2, random_state=42)

# Apply SMOTE to the training set only
smote = SMOTE(random_state=42)
X_train_resampled_female, y_train_resampled_female = smote.fit_resample(X_train_female, y_train_female)

# Initialize evaluation sets
eval_set = [(X_train_resampled_female, y_train_resampled_female), (X_val_female, y_val_female)]

female_model = xgb.XGBClassifier(eval_metric='merror', objective='multi:softprob', num_class=4)

female_model.fit(X_train_resampled_female, y_train_resampled_female, eval_set=eval_set, verbose=True)

# Retrieve evaluation results
results = female_model.evals_result()

# Calculate accuracy
train_accuracy = [1 - x for x in results['validation_0']['merror']]
test_accuracy = [1 - x for x in results['validation_1']['merror']]

# Plot accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Female Accuracy Curve')
plt.legend()
plt.savefig('female_accuracy_curve.png')
plt.show()

from sklearn.metrics import classification_report

# Make predictions on the test set
y_prob = female_model.predict_proba(X_val_female)
# Use np.argmax to convert probabilities to class predictions
y_pred = np.argmax(y_prob, axis=1)

# Generate the classification report
report = classification_report(y_val_female, y_pred)
print(report)
# Out:
# [0]	validation_0-merror:0.26359	validation_1-merror:0.23697
# [1]	validation_0-merror:0.24576	validation_1-merror:0.21763
# [2]	validation_0-merror:0.23246	validation_1-merror:0.20421
# [3]	validation_0-merror:0.22921	validation_1-merror:0.20585
# [4]	validation_0-merror:0.22752	validation_1-merror:0.20655
# [5]	validation_0-merror:0.22240	validation_1-merror:0.20261
# [6]	validation_0-merror:0.21819	validation_1-merror:0.20152
# [7]	validation_0-merror:0.21286	validation_1-merror:0.19750
# [8]	validation_0-merror:0.20961	validation_1-merror:0.19591
# [9]	validation_0-merror:0.20463	validation_1-merror:0.19013
# [10]	validation_0-merror:0.20204	validation_1-merror:0.18807
# [11]	validation_0-merror:0.19684	validation_1-merror:0.18417
# [12]	validation_0-merror:0.19226	validation_1-merror:0.17933
# [13]	validation_0-merror:0.18786	validation_1-merror:0.17473
# [14]	validation_0-merror:0.18557	validation_1-merror:0.17157
# [15]	validation_0-merror:0.18154	validation_1-merror:0.16814
# [16]	validation_0-merror:0.17769	validation_1-merror:0.16541
# [17]	validation_0-merror:0.17572	validation_1-merror:0.16459
# [18]	validation_0-merror:0.17470	validation_1-merror:0.16432
# [19]	validation_0-merror:0.17205	validation_1-merror:0.16292
# [20]	validation_0-merror:0.16980	validation_1-merror:0.16182
# [21]	validation_0-merror:0.16835	validation_1-merror:0.16054
# [22]	validation_0-merror:0.16605	validation_1-merror:0.15816
# [23]	validation_0-merror:0.16210	validation_1-merror:0.15457
# [24]	validation_0-merror:0.16047	validation_1-merror:0.15344
# [25]	validation_0-merror:0.15784	validation_1-merror:0.15321
# [26]	validation_0-merror:0.15682	validation_1-merror:0.15098
# [27]	validation_0-merror:0.15482	validation_1-merror:0.14989
# [28]	validation_0-merror:0.15144	validation_1-merror:0.14779
# [29]	validation_0-merror:0.14820	validation_1-merror:0.14588
# [30]	validation_0-merror:0.14681	validation_1-merror:0.14463
# [31]	validation_0-merror:0.14553	validation_1-merror:0.14506
# [32]	validation_0-merror:0.14348	validation_1-merror:0.14354
# [33]	validation_0-merror:0.14239	validation_1-merror:0.14287
# [34]	validation_0-merror:0.13990	validation_1-merror:0.14155
# [35]	validation_0-merror:0.13924	validation_1-merror:0.14014
# [36]	validation_0-merror:0.13704	validation_1-merror:0.13936
# [37]	validation_0-merror:0.13593	validation_1-merror:0.13886
# [38]	validation_0-merror:0.13402	validation_1-merror:0.13843
# [39]	validation_0-merror:0.13161	validation_1-merror:0.13706
# [40]	validation_0-merror:0.12938	validation_1-merror:0.13500
# [41]	validation_0-merror:0.12879	validation_1-merror:0.13484
# [42]	validation_0-merror:0.12652	validation_1-merror:0.13246
# [43]	validation_0-merror:0.12524	validation_1-merror:0.13164
# [44]	validation_0-merror:0.12434	validation_1-merror:0.13149
# [45]	validation_0-merror:0.12257	validation_1-merror:0.12938
# [46]	validation_0-merror:0.12091	validation_1-merror:0.12806
# [47]	validation_0-merror:0.12073	validation_1-merror:0.12778
# [48]	validation_0-merror:0.11890	validation_1-merror:0.12654
# [49]	validation_0-merror:0.11815	validation_1-merror:0.12591
# [50]	validation_0-merror:0.11759	validation_1-merror:0.12544
# [51]	validation_0-merror:0.11630	validation_1-merror:0.12482
# [52]	validation_0-merror:0.11542	validation_1-merror:0.12435
# [53]	validation_0-merror:0.11458	validation_1-merror:0.12373
# [54]	validation_0-merror:0.11360	validation_1-merror:0.12381
# [55]	validation_0-merror:0.11266	validation_1-merror:0.12314
# [56]	validation_0-merror:0.11130	validation_1-merror:0.12314
# [57]	validation_0-merror:0.11058	validation_1-merror:0.12209
# [58]	validation_0-merror:0.11008	validation_1-merror:0.12186
# [59]	validation_0-merror:0.10927	validation_1-merror:0.12193
# [60]	validation_0-merror:0.10856	validation_1-merror:0.12158
# [61]	validation_0-merror:0.10735	validation_1-merror:0.12178
# [62]	validation_0-merror:0.10611	validation_1-merror:0.12151
# [63]	validation_0-merror:0.10546	validation_1-merror:0.12135
# [64]	validation_0-merror:0.10441	validation_1-merror:0.12092
# [65]	validation_0-merror:0.10349	validation_1-merror:0.12045
# [66]	validation_0-merror:0.10219	validation_1-merror:0.11928
# [67]	validation_0-merror:0.10176	validation_1-merror:0.11920
# [68]	validation_0-merror:0.10081	validation_1-merror:0.11858
# [69]	validation_0-merror:0.10080	validation_1-merror:0.11850
# [70]	validation_0-merror:0.09947	validation_1-merror:0.11757
# [71]	validation_0-merror:0.09899	validation_1-merror:0.11784
# [72]	validation_0-merror:0.09819	validation_1-merror:0.11768
# [73]	validation_0-merror:0.09803	validation_1-merror:0.11753
# [74]	validation_0-merror:0.09796	validation_1-merror:0.11725
# [75]	validation_0-merror:0.09742	validation_1-merror:0.11679
# [76]	validation_0-merror:0.09699	validation_1-merror:0.11710
# [77]	validation_0-merror:0.09673	validation_1-merror:0.11667
# [78]	validation_0-merror:0.09582	validation_1-merror:0.11636
# [79]	validation_0-merror:0.09446	validation_1-merror:0.11538
# [80]	validation_0-merror:0.09422	validation_1-merror:0.11523
# [81]	validation_0-merror:0.09402	validation_1-merror:0.11531
# [82]	validation_0-merror:0.09356	validation_1-merror:0.11507
# [83]	validation_0-merror:0.09279	validation_1-merror:0.11441
# [84]	validation_0-merror:0.09190	validation_1-merror:0.11378
# [85]	validation_0-merror:0.09175	validation_1-merror:0.11351
# [86]	validation_0-merror:0.09100	validation_1-merror:0.11367
# [87]	validation_0-merror:0.09028	validation_1-merror:0.11332
# [88]	validation_0-merror:0.08974	validation_1-merror:0.11254
# [89]	validation_0-merror:0.08939	validation_1-merror:0.11258
# [90]	validation_0-merror:0.08903	validation_1-merror:0.11226
# [91]	validation_0-merror:0.08900	validation_1-merror:0.11238
# [92]	validation_0-merror:0.08867	validation_1-merror:0.11191
# [93]	validation_0-merror:0.08780	validation_1-merror:0.11129
# [94]	validation_0-merror:0.08717	validation_1-merror:0.11141
# [95]	validation_0-merror:0.08691	validation_1-merror:0.11156
# [96]	validation_0-merror:0.08599	validation_1-merror:0.11063
# [97]	validation_0-merror:0.08579	validation_1-merror:0.11012
# [98]	validation_0-merror:0.08506	validation_1-merror:0.10953
# [99]	validation_0-merror:0.08422	validation_1-merror:0.10875
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     21398
#          1.0       0.81      0.07      0.13       607
#          2.0       0.65      0.64      0.64      3334
#          3.0       1.00      1.00      1.00       306
#
#     accuracy                           0.89     25645
#    macro avg       0.84      0.67      0.68     25645
# weighted avg       0.89      0.89      0.88     25645

# %%
male_data = pd.read_csv('/kaggle/input/male-data/male_data.csv')
print(male_data.columns)
male_columns_to_drop = ['Family_Diabetes', 'Smoking', 'Alcohol', 'RegularMedicine', 'Stress', 'Pdiabetes', 'Diabetic', 'Diabetes_Status', 'HighChol', 'CholCheck', 'Stroke', 'HeartDiseaseorAttack', 'AnyHealthcare', 'NoDocbcCost', 'MentHlth', 'DiffWalk',
       'Education', 'Income', 'Polyuria', 'Polydipsia', 'weakness', 'Polyphagia', 'Genital thrush', 'Itching', 'Irritability', 'partial paresis',
       'muscle stiffness', 'Alopecia', 'Obesity', 'Patient_ID']


X_male = male_data.drop(columns=male_columns_to_drop, axis=1)
y_male = male_data['Diabetes_Status']

print(X_male.columns)
# Out:
# Index(['Age', 'Family_Diabetes', 'HighBP', 'PhysicallyActive', 'BMI',
#        'Smoking', 'Alcohol', 'Sleep', 'SoundSleep', 'RegularMedicine',
#        'JunkFood', 'Stress', 'BPLevel', 'Pdiabetes', 'UriationFreq',
#        'Diabetic', 'Diabetes_Status', 'HighChol', 'CholCheck', 'Stroke',
#        'HeartDiseaseorAttack', 'Fruits', 'Veggies', 'AnyHealthcare',
#        'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk',
#        'Education', 'Income', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'Patient_ID'],
#       dtype='object')
# Index(['Age', 'HighBP', 'PhysicallyActive', 'BMI', 'Sleep', 'SoundSleep',
#        'JunkFood', 'BPLevel', 'UriationFreq', 'Fruits', 'Veggies', 'GenHlth',
#        'PhysHlth', 'sudden weight loss', 'visual blurring', 'delayed healing'],
#       dtype='object')

# %%
# Split the data
X_train_male, X_val_male, y_train_male, y_val_male = train_test_split(X_male, y_male, test_size=0.2, random_state=42)

# Apply SMOTE to the training set only
smote = SMOTE(random_state=42)
X_train_resampled_male, y_train_resampled_male = smote.fit_resample(X_train_male, y_train_male)

# Initialize evaluation sets
eval_set = [(X_train_resampled_male, y_train_resampled_male), (X_val_male, y_val_male)]

male_model = xgb.XGBClassifier(eval_metric='merror', objective='multi:softprob', num_class=3)

male_model.fit(X_train_resampled_male, y_train_resampled_male, eval_set=eval_set, verbose=True)

# Retrieve evaluation results
results = male_model.evals_result()

# Calculate accuracy
train_accuracy = [1 - x for x in results['validation_0']['merror']]
test_accuracy = [1 - x for x in results['validation_1']['merror']]

# Plot accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Male Accuracy Curve')
plt.legend()
plt.savefig('male_accuracy_curve.png')
plt.show()

from sklearn.metrics import classification_report

# Make predictions on the test set
y_prob = male_model.predict_proba(X_val_male)
# Use np.argmax to convert probabilities to class predictions
y_pred = np.argmax(y_prob, axis=1)

# Generate the classification report
report = classification_report(y_val_male, y_pred)
print(report)
# Out:
# [0]	validation_0-merror:0.28621	validation_1-merror:0.23060
# [1]	validation_0-merror:0.26578	validation_1-merror:0.22428
# [2]	validation_0-merror:0.24851	validation_1-merror:0.20983
# [3]	validation_0-merror:0.23421	validation_1-merror:0.20421
# [4]	validation_0-merror:0.22330	validation_1-merror:0.19397
# [5]	validation_0-merror:0.21697	validation_1-merror:0.18322
# [6]	validation_0-merror:0.20882	validation_1-merror:0.17518
# [7]	validation_0-merror:0.20313	validation_1-merror:0.16798
# [8]	validation_0-merror:0.19389	validation_1-merror:0.15884
# [9]	validation_0-merror:0.18833	validation_1-merror:0.15120
# [10]	validation_0-merror:0.18442	validation_1-merror:0.14971
# [11]	validation_0-merror:0.17995	validation_1-merror:0.14580
# [12]	validation_0-merror:0.17643	validation_1-merror:0.14338
# [13]	validation_0-merror:0.17507	validation_1-merror:0.14321
# [14]	validation_0-merror:0.17123	validation_1-merror:0.13899
# [15]	validation_0-merror:0.16791	validation_1-merror:0.13596
# [16]	validation_0-merror:0.16423	validation_1-merror:0.13315
# [17]	validation_0-merror:0.16034	validation_1-merror:0.13113
# [18]	validation_0-merror:0.15773	validation_1-merror:0.12850
# [19]	validation_0-merror:0.15705	validation_1-merror:0.12854
# [20]	validation_0-merror:0.15469	validation_1-merror:0.12749
# [21]	validation_0-merror:0.15206	validation_1-merror:0.12257
# [22]	validation_0-merror:0.14794	validation_1-merror:0.11901
# [23]	validation_0-merror:0.14538	validation_1-merror:0.11682
# [24]	validation_0-merror:0.14458	validation_1-merror:0.11629
# [25]	validation_0-merror:0.14272	validation_1-merror:0.11537
# [26]	validation_0-merror:0.14017	validation_1-merror:0.11291
# [27]	validation_0-merror:0.13862	validation_1-merror:0.11286
# [28]	validation_0-merror:0.13587	validation_1-merror:0.11014
# [29]	validation_0-merror:0.13454	validation_1-merror:0.10966
# [30]	validation_0-merror:0.13335	validation_1-merror:0.10913
# [31]	validation_0-merror:0.13155	validation_1-merror:0.10891
# [32]	validation_0-merror:0.13031	validation_1-merror:0.10856
# [33]	validation_0-merror:0.12884	validation_1-merror:0.10733
# [34]	validation_0-merror:0.12775	validation_1-merror:0.10737
# [35]	validation_0-merror:0.12690	validation_1-merror:0.10764
# [36]	validation_0-merror:0.12541	validation_1-merror:0.10676
# [37]	validation_0-merror:0.12380	validation_1-merror:0.10505
# [38]	validation_0-merror:0.12284	validation_1-merror:0.10404
# [39]	validation_0-merror:0.12179	validation_1-merror:0.10412
# [40]	validation_0-merror:0.12086	validation_1-merror:0.10404
# [41]	validation_0-merror:0.12007	validation_1-merror:0.10417
# [42]	validation_0-merror:0.11878	validation_1-merror:0.10395
# [43]	validation_0-merror:0.11831	validation_1-merror:0.10382
# [44]	validation_0-merror:0.11735	validation_1-merror:0.10289
# [45]	validation_0-merror:0.11672	validation_1-merror:0.10285
# [46]	validation_0-merror:0.11589	validation_1-merror:0.10267
# [47]	validation_0-merror:0.11545	validation_1-merror:0.10149
# [48]	validation_0-merror:0.11463	validation_1-merror:0.10118
# [49]	validation_0-merror:0.11358	validation_1-merror:0.10096
# [50]	validation_0-merror:0.11243	validation_1-merror:0.10048
# [51]	validation_0-merror:0.11131	validation_1-merror:0.10052
# [52]	validation_0-merror:0.11013	validation_1-merror:0.09991
# [53]	validation_0-merror:0.10894	validation_1-merror:0.09951
# [54]	validation_0-merror:0.10802	validation_1-merror:0.09934
# [55]	validation_0-merror:0.10780	validation_1-merror:0.09885
# [56]	validation_0-merror:0.10637	validation_1-merror:0.09890
# [57]	validation_0-merror:0.10603	validation_1-merror:0.09894
# [58]	validation_0-merror:0.10533	validation_1-merror:0.09885
# [59]	validation_0-merror:0.10492	validation_1-merror:0.09859
# [60]	validation_0-merror:0.10394	validation_1-merror:0.09881
# [61]	validation_0-merror:0.10274	validation_1-merror:0.09868
# [62]	validation_0-merror:0.10232	validation_1-merror:0.09885
# [63]	validation_0-merror:0.10145	validation_1-merror:0.09859
# [64]	validation_0-merror:0.10043	validation_1-merror:0.09855
# [65]	validation_0-merror:0.10022	validation_1-merror:0.09837
# [66]	validation_0-merror:0.09945	validation_1-merror:0.09833
# [67]	validation_0-merror:0.09933	validation_1-merror:0.09806
# [68]	validation_0-merror:0.09885	validation_1-merror:0.09771
# [69]	validation_0-merror:0.09855	validation_1-merror:0.09745
# [70]	validation_0-merror:0.09805	validation_1-merror:0.09784
# [71]	validation_0-merror:0.09782	validation_1-merror:0.09771
# [72]	validation_0-merror:0.09749	validation_1-merror:0.09798
# [73]	validation_0-merror:0.09705	validation_1-merror:0.09789
# [74]	validation_0-merror:0.09664	validation_1-merror:0.09745
# [75]	validation_0-merror:0.09585	validation_1-merror:0.09727
# [76]	validation_0-merror:0.09568	validation_1-merror:0.09714
# [77]	validation_0-merror:0.09538	validation_1-merror:0.09705
# [78]	validation_0-merror:0.09477	validation_1-merror:0.09675
# [79]	validation_0-merror:0.09336	validation_1-merror:0.09661
# [80]	validation_0-merror:0.09288	validation_1-merror:0.09622
# [81]	validation_0-merror:0.09260	validation_1-merror:0.09600
# [82]	validation_0-merror:0.09179	validation_1-merror:0.09617
# [83]	validation_0-merror:0.09099	validation_1-merror:0.09560
# [84]	validation_0-merror:0.09064	validation_1-merror:0.09547
# [85]	validation_0-merror:0.09038	validation_1-merror:0.09521
# [86]	validation_0-merror:0.09000	validation_1-merror:0.09534
# [87]	validation_0-merror:0.08982	validation_1-merror:0.09503
# [88]	validation_0-merror:0.08933	validation_1-merror:0.09477
# [89]	validation_0-merror:0.08867	validation_1-merror:0.09446
# [90]	validation_0-merror:0.08825	validation_1-merror:0.09459
# [91]	validation_0-merror:0.08794	validation_1-merror:0.09468
# [92]	validation_0-merror:0.08760	validation_1-merror:0.09473
# [93]	validation_0-merror:0.08700	validation_1-merror:0.09446
# [94]	validation_0-merror:0.08644	validation_1-merror:0.09446
# [95]	validation_0-merror:0.08632	validation_1-merror:0.09451
# [96]	validation_0-merror:0.08581	validation_1-merror:0.09437
# [97]	validation_0-merror:0.08559	validation_1-merror:0.09464
# [98]	validation_0-merror:0.08501	validation_1-merror:0.09442
# [99]	validation_0-merror:0.08405	validation_1-merror:0.09394
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.96      0.95     18703
#          1.0       0.83      0.19      0.31       583
#          2.0       0.77      0.72      0.74      3485
#
#     accuracy                           0.91     22771
#    macro avg       0.84      0.62      0.66     22771
# weighted avg       0.90      0.91      0.90     22771

# %%
# saving male model and female model
male_model.save_model('xgboost_male.json')
female_model.save_model('xgboost_female.json')
