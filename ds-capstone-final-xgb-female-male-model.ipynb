# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Female Model: Preprocessing

# %%
import xgboost as xgb
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFECV
from imblearn.over_sampling import SMOTE
import warnings

female_data = pd.read_csv('/kaggle/input/female-data/female_data.csv')
print(female_data.columns)
female_columns_to_drop = ['Family_Diabetes', 'Smoking', 'Alcohol', 'RegularMedicine', 'Stress', 'Pdiabetes', 'Diabetic', 'Diabetes_Status', 'CholCheck', 'Stroke', 'HeartDiseaseorAttack', 'AnyHealthcare',
       'NoDocbcCost', 'MentHlth', 'DiffWalk',
       'Education', 'Income', 'Glucose', 'SkinThickness', 'Insulin',
       'DiabetesPedigreeFunction', 'unexplained prenetal loss', 'Large Child or Birth Default', 'Sedentary Lifestyle', 'Polyuria', 'Polydipsia', 'weakness', 'Polyphagia', 'Genital thrush',
       'Itching', 'Irritability', 'partial paresis',
       'muscle stiffness', 'Alopecia', 'Patient_ID', 'Obesity']

X_female = female_data.drop(columns=female_columns_to_drop, axis=1)
y_female = female_data['Diabetes_Status']

print(X_female.columns)
# Out:
# Index(['Age', 'Family_Diabetes', 'HighBP', 'PhysicallyActive', 'BMI',
#        'Smoking', 'Alcohol', 'Sleep', 'SoundSleep', 'RegularMedicine',
#        'JunkFood', 'Stress', 'BPLevel', 'Pregnancies', 'Pdiabetes',
#        'UriationFreq', 'Diabetic', 'Diabetes_Status', 'HighChol', 'CholCheck',
#        'Stroke', 'HeartDiseaseorAttack', 'Fruits', 'Veggies', 'AnyHealthcare',
#        'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk',
#        'Education', 'Income', 'Glucose', 'SkinThickness', 'Insulin',
#        'DiabetesPedigreeFunction', 'Gestation in previous Pregnancy',
#        'unexplained prenetal loss', 'Large Child or Birth Default', 'PCOS',
#        'Sedentary Lifestyle', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'Patient_ID', 'Pregnant'],
#       dtype='object')
# Index(['Age', 'HighBP', 'PhysicallyActive', 'BMI', 'Sleep', 'SoundSleep',
#        'JunkFood', 'BPLevel', 'Pregnancies', 'UriationFreq', 'HighChol',
#        'Fruits', 'Veggies', 'GenHlth', 'PhysHlth',
#        'Gestation in previous Pregnancy', 'PCOS', 'sudden weight loss',
#        'visual blurring', 'delayed healing', 'Pregnant'],
#       dtype='object')

# %%
# Split the data
X_train_female, X_val_female, y_train_female, y_val_female = train_test_split(X_female, y_female, test_size=0.2, random_state=42)

# Apply SMOTE to the training set only
smote = SMOTE(random_state=42)
X_train_resampled_female, y_train_resampled_female = smote.fit_resample(X_train_female, y_train_female)

# Initialize evaluation sets
eval_set = [(X_train_resampled_female, y_train_resampled_female), (X_val_female, y_val_female)]

female_model = xgb.XGBClassifier(eval_metric='merror', objective='multi:softprob', num_class=4)

female_model.fit(X_train_resampled_female, y_train_resampled_female, eval_set=eval_set, verbose=True)

# Retrieve evaluation results
results = female_model.evals_result()

# Calculate accuracy
train_accuracy = [1 - x for x in results['validation_0']['merror']]
test_accuracy = [1 - x for x in results['validation_1']['merror']]

# Plot accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Female Accuracy Curve')
plt.legend()
plt.savefig('female_accuracy_curve.png')
plt.show()

from sklearn.metrics import classification_report

# Make predictions on the test set
y_prob = female_model.predict_proba(X_val_female)
# Use np.argmax to convert probabilities to class predictions
y_pred = np.argmax(y_prob, axis=1)

# Generate the classification report
report = classification_report(y_val_female, y_pred)
print(report)
# Out:
# [0]	validation_0-merror:0.26308	validation_1-merror:0.23681
# [1]	validation_0-merror:0.24459	validation_1-merror:0.21595
# [2]	validation_0-merror:0.24001	validation_1-merror:0.21373
# [3]	validation_0-merror:0.22905	validation_1-merror:0.21380
# [4]	validation_0-merror:0.22577	validation_1-merror:0.21505
# [5]	validation_0-merror:0.22217	validation_1-merror:0.21505
# [6]	validation_0-merror:0.21837	validation_1-merror:0.20729
# [7]	validation_0-merror:0.20975	validation_1-merror:0.20066
# [8]	validation_0-merror:0.20635	validation_1-merror:0.19789
# [9]	validation_0-merror:0.20242	validation_1-merror:0.19286
# [10]	validation_0-merror:0.19932	validation_1-merror:0.18869
# [11]	validation_0-merror:0.19543	validation_1-merror:0.18631
# [12]	validation_0-merror:0.19088	validation_1-merror:0.18120
# [13]	validation_0-merror:0.18930	validation_1-merror:0.17867
# [14]	validation_0-merror:0.18504	validation_1-merror:0.17528
# [15]	validation_0-merror:0.18369	validation_1-merror:0.17274
# [16]	validation_0-merror:0.18072	validation_1-merror:0.17118
# [17]	validation_0-merror:0.17807	validation_1-merror:0.16826
# [18]	validation_0-merror:0.17659	validation_1-merror:0.16615
# [19]	validation_0-merror:0.17398	validation_1-merror:0.16401
# [20]	validation_0-merror:0.17009	validation_1-merror:0.16081
# [21]	validation_0-merror:0.16687	validation_1-merror:0.15824
# [22]	validation_0-merror:0.16152	validation_1-merror:0.15621
# [23]	validation_0-merror:0.15932	validation_1-merror:0.15293
# [24]	validation_0-merror:0.15777	validation_1-merror:0.15317
# [25]	validation_0-merror:0.15624	validation_1-merror:0.15188
# [26]	validation_0-merror:0.15321	validation_1-merror:0.15009
# [27]	validation_0-merror:0.15168	validation_1-merror:0.14950
# [28]	validation_0-merror:0.15014	validation_1-merror:0.14896
# [29]	validation_0-merror:0.14922	validation_1-merror:0.14900
# [30]	validation_0-merror:0.14791	validation_1-merror:0.14740
# [31]	validation_0-merror:0.14738	validation_1-merror:0.14634
# [32]	validation_0-merror:0.14591	validation_1-merror:0.14564
# [33]	validation_0-merror:0.14208	validation_1-merror:0.14038
# [34]	validation_0-merror:0.14130	validation_1-merror:0.13913
# [35]	validation_0-merror:0.14044	validation_1-merror:0.13749
# [36]	validation_0-merror:0.13833	validation_1-merror:0.13695
# [37]	validation_0-merror:0.13638	validation_1-merror:0.13472
# [38]	validation_0-merror:0.13451	validation_1-merror:0.13352
# [39]	validation_0-merror:0.13391	validation_1-merror:0.13305
# [40]	validation_0-merror:0.13176	validation_1-merror:0.13133
# [41]	validation_0-merror:0.13012	validation_1-merror:0.13016
# [42]	validation_0-merror:0.12761	validation_1-merror:0.12884
# [43]	validation_0-merror:0.12659	validation_1-merror:0.12845
# [44]	validation_0-merror:0.12537	validation_1-merror:0.12794
# [45]	validation_0-merror:0.12269	validation_1-merror:0.12735
# [46]	validation_0-merror:0.12118	validation_1-merror:0.12657
# [47]	validation_0-merror:0.12010	validation_1-merror:0.12654
# [48]	validation_0-merror:0.11917	validation_1-merror:0.12587
# [49]	validation_0-merror:0.11838	validation_1-merror:0.12599
# [50]	validation_0-merror:0.11744	validation_1-merror:0.12603
# [51]	validation_0-merror:0.11641	validation_1-merror:0.12525
# [52]	validation_0-merror:0.11645	validation_1-merror:0.12490
# [53]	validation_0-merror:0.11572	validation_1-merror:0.12443
# [54]	validation_0-merror:0.11540	validation_1-merror:0.12381
# [55]	validation_0-merror:0.11527	validation_1-merror:0.12384
# [56]	validation_0-merror:0.11434	validation_1-merror:0.12318
# [57]	validation_0-merror:0.11344	validation_1-merror:0.12279
# [58]	validation_0-merror:0.11180	validation_1-merror:0.12271
# [59]	validation_0-merror:0.11111	validation_1-merror:0.12256
# [60]	validation_0-merror:0.11073	validation_1-merror:0.12240
# [61]	validation_0-merror:0.10937	validation_1-merror:0.12205
# [62]	validation_0-merror:0.10925	validation_1-merror:0.12182
# [63]	validation_0-merror:0.10764	validation_1-merror:0.12170
# [64]	validation_0-merror:0.10737	validation_1-merror:0.12088
# [65]	validation_0-merror:0.10708	validation_1-merror:0.12065
# [66]	validation_0-merror:0.10622	validation_1-merror:0.12026
# [67]	validation_0-merror:0.10537	validation_1-merror:0.11971
# [68]	validation_0-merror:0.10416	validation_1-merror:0.11944
# [69]	validation_0-merror:0.10325	validation_1-merror:0.11815
# [70]	validation_0-merror:0.10260	validation_1-merror:0.11800
# [71]	validation_0-merror:0.10136	validation_1-merror:0.11776
# [72]	validation_0-merror:0.10063	validation_1-merror:0.11722
# [73]	validation_0-merror:0.10005	validation_1-merror:0.11667
# [74]	validation_0-merror:0.09966	validation_1-merror:0.11651
# [75]	validation_0-merror:0.09915	validation_1-merror:0.11620
# [76]	validation_0-merror:0.09810	validation_1-merror:0.11546
# [77]	validation_0-merror:0.09757	validation_1-merror:0.11523
# [78]	validation_0-merror:0.09661	validation_1-merror:0.11484
# [79]	validation_0-merror:0.09574	validation_1-merror:0.11499
# [80]	validation_0-merror:0.09536	validation_1-merror:0.11464
# [81]	validation_0-merror:0.09510	validation_1-merror:0.11417
# [82]	validation_0-merror:0.09442	validation_1-merror:0.11417
# [83]	validation_0-merror:0.09415	validation_1-merror:0.11417
# [84]	validation_0-merror:0.09355	validation_1-merror:0.11375
# [85]	validation_0-merror:0.09318	validation_1-merror:0.11359
# [86]	validation_0-merror:0.09248	validation_1-merror:0.11339
# [87]	validation_0-merror:0.09196	validation_1-merror:0.11297
# [88]	validation_0-merror:0.09108	validation_1-merror:0.11203
# [89]	validation_0-merror:0.09024	validation_1-merror:0.11176
# [90]	validation_0-merror:0.08951	validation_1-merror:0.11043
# [91]	validation_0-merror:0.08916	validation_1-merror:0.11039
# [92]	validation_0-merror:0.08881	validation_1-merror:0.11070
# [93]	validation_0-merror:0.08855	validation_1-merror:0.11043
# [94]	validation_0-merror:0.08788	validation_1-merror:0.11020
# [95]	validation_0-merror:0.08710	validation_1-merror:0.10942
# [96]	validation_0-merror:0.08673	validation_1-merror:0.10899
# [97]	validation_0-merror:0.08613	validation_1-merror:0.10891
# [98]	validation_0-merror:0.08590	validation_1-merror:0.10875
# [99]	validation_0-merror:0.08503	validation_1-merror:0.10891
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94     21398
#          1.0       0.82      0.07      0.12       607
#          2.0       0.65      0.64      0.64      3334
#          3.0       1.00      1.00      1.00       306
#
#     accuracy                           0.89     25645
#    macro avg       0.85      0.66      0.68     25645
# weighted avg       0.89      0.89      0.88     25645

# %%
male_data = pd.read_csv('/kaggle/input/male-data/male_data.csv')
print(male_data.columns)
male_columns_to_drop = ['Family_Diabetes', 'Smoking', 'Alcohol', 'RegularMedicine', 'Stress', 'Pdiabetes', 'Diabetic', 'Diabetes_Status', 'CholCheck', 'Stroke', 'HeartDiseaseorAttack', 'AnyHealthcare', 'NoDocbcCost', 'MentHlth', 'DiffWalk',
       'Education', 'Income', 'Polyuria', 'Polydipsia', 'weakness', 'Polyphagia', 'Genital thrush', 'Itching', 'Irritability', 'partial paresis',
       'muscle stiffness', 'Alopecia', 'Obesity', 'Patient_ID']


X_male = male_data.drop(columns=male_columns_to_drop, axis=1)
y_male = male_data['Diabetes_Status']

print(X_male.columns)
# Out:
# Index(['Age', 'Family_Diabetes', 'HighBP', 'PhysicallyActive', 'BMI',
#        'Smoking', 'Alcohol', 'Sleep', 'SoundSleep', 'RegularMedicine',
#        'JunkFood', 'Stress', 'BPLevel', 'Pdiabetes', 'UriationFreq',
#        'Diabetic', 'Diabetes_Status', 'HighChol', 'CholCheck', 'Stroke',
#        'HeartDiseaseorAttack', 'Fruits', 'Veggies', 'AnyHealthcare',
#        'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk',
#        'Education', 'Income', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'Patient_ID'],
#       dtype='object')
# Index(['Age', 'HighBP', 'PhysicallyActive', 'BMI', 'Sleep', 'SoundSleep',
#        'JunkFood', 'BPLevel', 'UriationFreq', 'HighChol', 'Fruits', 'Veggies',
#        'GenHlth', 'PhysHlth', 'sudden weight loss', 'visual blurring',
#        'delayed healing'],
#       dtype='object')

# %%
# Split the data
X_train_male, X_val_male, y_train_male, y_val_male = train_test_split(X_male, y_male, test_size=0.2, random_state=42)

# Apply SMOTE to the training set only
smote = SMOTE(random_state=42)
X_train_resampled_male, y_train_resampled_male = smote.fit_resample(X_train_male, y_train_male)

# Initialize evaluation sets
eval_set = [(X_train_resampled_male, y_train_resampled_male), (X_val_male, y_val_male)]

male_model = xgb.XGBClassifier(eval_metric='merror', objective='multi:softprob', num_class=3)

male_model.fit(X_train_resampled_male, y_train_resampled_male, eval_set=eval_set, verbose=True)

# Retrieve evaluation results
results = male_model.evals_result()

# Calculate accuracy
train_accuracy = [1 - x for x in results['validation_0']['merror']]
test_accuracy = [1 - x for x in results['validation_1']['merror']]

# Plot accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Male Accuracy Curve')
plt.legend()
plt.savefig('male_accuracy_curve.png')
plt.show()

from sklearn.metrics import classification_report

# Make predictions on the test set
y_prob = male_model.predict_proba(X_val_male)
# Use np.argmax to convert probabilities to class predictions
y_pred = np.argmax(y_prob, axis=1)

# Generate the classification report
report = classification_report(y_val_male, y_pred)
print(report)
# Out:
# [0]	validation_0-merror:0.27904	validation_1-merror:0.22955
# [1]	validation_0-merror:0.26862	validation_1-merror:0.22665
# [2]	validation_0-merror:0.24862	validation_1-merror:0.21817
# [3]	validation_0-merror:0.23905	validation_1-merror:0.20877
# [4]	validation_0-merror:0.22910	validation_1-merror:0.20416
# [5]	validation_0-merror:0.22089	validation_1-merror:0.19033
# [6]	validation_0-merror:0.21472	validation_1-merror:0.18076
# [7]	validation_0-merror:0.20782	validation_1-merror:0.17487
# [8]	validation_0-merror:0.19894	validation_1-merror:0.16214
# [9]	validation_0-merror:0.19244	validation_1-merror:0.15362
# [10]	validation_0-merror:0.18771	validation_1-merror:0.14949
# [11]	validation_0-merror:0.18191	validation_1-merror:0.14492
# [12]	validation_0-merror:0.17692	validation_1-merror:0.13956
# [13]	validation_0-merror:0.17379	validation_1-merror:0.13667
# [14]	validation_0-merror:0.16899	validation_1-merror:0.13074
# [15]	validation_0-merror:0.16533	validation_1-merror:0.12810
# [16]	validation_0-merror:0.16340	validation_1-merror:0.12634
# [17]	validation_0-merror:0.16023	validation_1-merror:0.12595
# [18]	validation_0-merror:0.15887	validation_1-merror:0.12503
# [19]	validation_0-merror:0.15560	validation_1-merror:0.12393
# [20]	validation_0-merror:0.15455	validation_1-merror:0.12274
# [21]	validation_0-merror:0.14954	validation_1-merror:0.11831
# [22]	validation_0-merror:0.14727	validation_1-merror:0.11765
# [23]	validation_0-merror:0.14375	validation_1-merror:0.11515
# [24]	validation_0-merror:0.14136	validation_1-merror:0.11370
# [25]	validation_0-merror:0.14050	validation_1-merror:0.11269
# [26]	validation_0-merror:0.13867	validation_1-merror:0.11203
# [27]	validation_0-merror:0.13776	validation_1-merror:0.11155
# [28]	validation_0-merror:0.13502	validation_1-merror:0.11062
# [29]	validation_0-merror:0.13417	validation_1-merror:0.10974
# [30]	validation_0-merror:0.13290	validation_1-merror:0.10983
# [31]	validation_0-merror:0.13071	validation_1-merror:0.10904
# [32]	validation_0-merror:0.12961	validation_1-merror:0.10856
# [33]	validation_0-merror:0.12897	validation_1-merror:0.10834
# [34]	validation_0-merror:0.12765	validation_1-merror:0.10781
# [35]	validation_0-merror:0.12705	validation_1-merror:0.10764
# [36]	validation_0-merror:0.12620	validation_1-merror:0.10724
# [37]	validation_0-merror:0.12477	validation_1-merror:0.10650
# [38]	validation_0-merror:0.12337	validation_1-merror:0.10632
# [39]	validation_0-merror:0.12159	validation_1-merror:0.10540
# [40]	validation_0-merror:0.12097	validation_1-merror:0.10522
# [41]	validation_0-merror:0.12015	validation_1-merror:0.10522
# [42]	validation_0-merror:0.11889	validation_1-merror:0.10456
# [43]	validation_0-merror:0.11785	validation_1-merror:0.10430
# [44]	validation_0-merror:0.11720	validation_1-merror:0.10386
# [45]	validation_0-merror:0.11611	validation_1-merror:0.10382
# [46]	validation_0-merror:0.11512	validation_1-merror:0.10390
# [47]	validation_0-merror:0.11414	validation_1-merror:0.10377
# [48]	validation_0-merror:0.11339	validation_1-merror:0.10342
# [49]	validation_0-merror:0.11167	validation_1-merror:0.10298
# [50]	validation_0-merror:0.11102	validation_1-merror:0.10202
# [51]	validation_0-merror:0.10991	validation_1-merror:0.10188
# [52]	validation_0-merror:0.10927	validation_1-merror:0.10149
# [53]	validation_0-merror:0.10920	validation_1-merror:0.10153
# [54]	validation_0-merror:0.10784	validation_1-merror:0.10083
# [55]	validation_0-merror:0.10684	validation_1-merror:0.10065
# [56]	validation_0-merror:0.10612	validation_1-merror:0.10013
# [57]	validation_0-merror:0.10589	validation_1-merror:0.09995
# [58]	validation_0-merror:0.10499	validation_1-merror:0.09964
# [59]	validation_0-merror:0.10388	validation_1-merror:0.09942
# [60]	validation_0-merror:0.10265	validation_1-merror:0.09929
# [61]	validation_0-merror:0.10184	validation_1-merror:0.09964
# [62]	validation_0-merror:0.10121	validation_1-merror:0.09921
# [63]	validation_0-merror:0.10063	validation_1-merror:0.09929
# [64]	validation_0-merror:0.10001	validation_1-merror:0.09868
# [65]	validation_0-merror:0.09951	validation_1-merror:0.09841
# [66]	validation_0-merror:0.09848	validation_1-merror:0.09846
# [67]	validation_0-merror:0.09753	validation_1-merror:0.09872
# [68]	validation_0-merror:0.09687	validation_1-merror:0.09828
# [69]	validation_0-merror:0.09605	validation_1-merror:0.09824
# [70]	validation_0-merror:0.09563	validation_1-merror:0.09859
# [71]	validation_0-merror:0.09513	validation_1-merror:0.09833
# [72]	validation_0-merror:0.09475	validation_1-merror:0.09850
# [73]	validation_0-merror:0.09437	validation_1-merror:0.09820
# [74]	validation_0-merror:0.09359	validation_1-merror:0.09833
# [75]	validation_0-merror:0.09310	validation_1-merror:0.09828
# [76]	validation_0-merror:0.09251	validation_1-merror:0.09881
# [77]	validation_0-merror:0.09237	validation_1-merror:0.09855
# [78]	validation_0-merror:0.09194	validation_1-merror:0.09841
# [79]	validation_0-merror:0.09129	validation_1-merror:0.09824
# [80]	validation_0-merror:0.09102	validation_1-merror:0.09833
# [81]	validation_0-merror:0.09055	validation_1-merror:0.09762
# [82]	validation_0-merror:0.08999	validation_1-merror:0.09727
# [83]	validation_0-merror:0.08939	validation_1-merror:0.09762
# [84]	validation_0-merror:0.08884	validation_1-merror:0.09732
# [85]	validation_0-merror:0.08838	validation_1-merror:0.09657
# [86]	validation_0-merror:0.08779	validation_1-merror:0.09648
# [87]	validation_0-merror:0.08710	validation_1-merror:0.09626
# [88]	validation_0-merror:0.08660	validation_1-merror:0.09591
# [89]	validation_0-merror:0.08629	validation_1-merror:0.09596
# [90]	validation_0-merror:0.08560	validation_1-merror:0.09547
# [91]	validation_0-merror:0.08507	validation_1-merror:0.09538
# [92]	validation_0-merror:0.08496	validation_1-merror:0.09512
# [93]	validation_0-merror:0.08417	validation_1-merror:0.09420
# [94]	validation_0-merror:0.08356	validation_1-merror:0.09424
# [95]	validation_0-merror:0.08340	validation_1-merror:0.09394
# [96]	validation_0-merror:0.08258	validation_1-merror:0.09420
# [97]	validation_0-merror:0.08256	validation_1-merror:0.09442
# [98]	validation_0-merror:0.08230	validation_1-merror:0.09437
# [99]	validation_0-merror:0.08179	validation_1-merror:0.09429
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.96      0.95     18703
#          1.0       0.76      0.19      0.30       583
#          2.0       0.76      0.72      0.74      3485
#
#     accuracy                           0.91     22771
#    macro avg       0.82      0.62      0.66     22771
# weighted avg       0.90      0.91      0.90     22771

# %%
# saving male model and female model
male_model.save_model('xgboost_male.json')
female_model.save_model('xgboost_female.json')

# %%
male_list = ['Age', 'HighBP', 'PhysicallyActive', 'BMI', 'Sleep', 'SoundSleep',
       'JunkFood', 'BPLevel', 'UriationFreq', 'HighChol', 'Fruits', 'Veggies',
       'GenHlth', 'PhysHlth', 'sudden weight loss', 'visual blurring',
       'delayed healing']

female_list = ['Age', 'HighBP', 'PhysicallyActive', 'BMI', 'Sleep', 'SoundSleep',
       'JunkFood', 'BPLevel', 'Pregnancies', 'UriationFreq', 'HighChol',
       'Fruits', 'Veggies', 'GenHlth', 'PhysHlth',
       'Gestation in previous Pregnancy', 'PCOS', 'sudden weight loss',
       'visual blurring', 'delayed healing', 'Pregnant']
intersection = list(set(male_list) & set(female_list))
# print(intersection)

difference1 = list(set(female_list) - set(intersection))
# print(difference1)

difference2 = list(set(male_list) - set(intersection))
print(difference2)
# Out:
# []
